# %% [markdown]
# # Data

# %%
import numpy as np
import pandas as pd
import ast
import json
import os
#os.environ['KMP_WARNINGS'] = '0'
#os.environ['OMP_NUM_THREADS'] = '1'

# %%
# Read the CSV file containing the metadata for articles from January 1, 2000 to May 15, 2023
#df = pd.read_csv('nyt-metadata.csv', low_memory=False)
# Read the CSV file containing the metadata for articles from May 15, 2023 to May 14, 2024
df = pd.read_csv('nyt-metadata-2.csv', usecols=lambda column: column != 'Unnamed: 0', low_memory=False)

# %%
df.head()
# Out:
#                                             abstract  \
# 0  Economic hardship, climate change, political i...
# 1  It’s election night in America. Stay away from...
# 2  Tom is stressed in dress shoes, Shiv hides ben...
# 3  No corrections appeared in print on Monday, Ma...
# 4     Quotation of the Day for Monday, May 15, 2023.
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/14/us/migrants...
# 1  https://www.nytimes.com/2023/05/14/arts/televi...
# 2  https://www.nytimes.com/2023/05/14/style/succe...
# 3  https://www.nytimes.com/2023/05/14/pageoneplus...
# 4  https://www.nytimes.com/2023/05/14/pageoneplus...
#
#                                              snippet  \
# 0  Economic hardship, climate change, political i...
# 1  It’s election night in America. Stay away from...
# 2  Tom is stressed in dress shoes, Shiv hides ben...
# 3  No corrections appeared in print on Monday, Ma...
# 4     Quotation of the Day for Monday, May 15, 2023.
#
#                                       lead_paragraph print_section  \
# 0  Relative quiet has prevailed along the souther...             A
# 1  The day before Logan Roy died, he delivered a ...           NaN
# 2  This article contains spoilers for Episode 8 o...           NaN
# 3  Errors are corrected during the press run when...           NaN
# 4  “For me, it was time to give back the love the...             A
#
#    print_page              source  \
# 0        14.0  The New York Times
# 1         NaN  The New York Times
# 2         NaN  The New York Times
# 3         NaN  The New York Times
# 4         2.0  The New York Times
#
#                                           multimedia  \
# 0  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3                                                 []
# 4                                                 []
#
#                                             headline  \
# 0  {'main': 'Title 42 Is Gone, but Not the Condit...
# 1  {'main': '‘Succession’ Season 4, Episode 8 Rec...
# 2  {'main': '‘Succession’ Style, Episode 8: Some ...
# 3  {'main': 'No Corrections: May 15, 2023', 'kick...
# 4  {'main': 'Quotation of the Day: When Your Cham...
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Illegal Immigra...
# 1  [{'name': 'creative_works', 'value': 'Successi...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                     pub_date document_type    news_desk section_name  \
# 0  2023-05-15 01:24:42+00:00       article     National         U.S.
# 1  2023-05-15 02:01:05+00:00       article      Culture         Arts
# 2  2023-05-15 02:15:04+00:00       article       Styles        Style
# 3  2023-05-15 03:55:48+00:00       article  Corrections  Corrections
# 4  2023-05-15 03:55:57+00:00       article      Summary  Corrections
#
#   subsection_name                                             byline  \
# 0             NaN  {'original': 'By Miriam Jordan', 'person': [{'...
# 1      Television  {'original': 'By Noel Murray', 'person': [{'fi...
# 2             NaN  {'original': 'By The Styles Desk', 'person': [...
# 3             NaN  {'original': '', 'person': [], 'organization':...
# 4             NaN  {'original': '', 'person': [], 'organization':...
#
#   type_of_material                                                _id  \
# 0             News  nyt://article/3d95da14-0c64-59c6-bae2-02b151ad...
# 1             News  nyt://article/17f6f628-2939-541b-a0e8-5c503fa6...
# 2             News  nyt://article/70773662-4815-5d40-8460-b438aa44...
# 3             News  nyt://article/199d026e-1372-51a3-adf0-c82abeeb...
# 4             News  nyt://article/5f4b7ea7-88f4-5178-884f-ae28530b...
#
#    word_count                                                uri
# 0        1217  nyt://article/3d95da14-0c64-59c6-bae2-02b151ad...
# 1        1495  nyt://article/17f6f628-2939-541b-a0e8-5c503fa6...
# 2         665  nyt://article/70773662-4815-5d40-8460-b438aa44...
# 3          52  nyt://article/199d026e-1372-51a3-adf0-c82abeeb...
# 4          42  nyt://article/5f4b7ea7-88f4-5178-884f-ae28530b...

# %% [markdown]
# # Cleaning

# %%
# Drop columns that are not needed
columns_to_drop = ['web_url', 
                   'snippet', 
                   'lead_paragraph', 
                   'print_section', 
                   'print_page', 
                   'source', 
                   'multimedia', 
                   'news_desk',
                   'byline',
                   '_id',
                   'uri',
                   'subsection_name',
                   'word_count',
                   'keywords']
df.drop(columns=columns_to_drop, inplace=True)

# Drop rows with missing abstracts
drop_rows = df[df['abstract'].isnull()].index
df.drop(drop_rows, inplace=True)

# Change the date column to datetime
df['pub_date'] = pd.to_datetime(df['pub_date'])

# Change the abstract column to string
df['abstract'] = df['abstract'].astype(str)

# %%
# Function to extract the 'main' value from JSON-like strings
def extract_main(headline_str):
    try:
        # Safely evaluate the string to convert it to a dictionary
        json_dict = ast.literal_eval(headline_str)
        # Access and return the 'main' key
        return json_dict.get('main', None)
    except (ValueError, SyntaxError):
        return None

# Apply the function to the 'headline' column
df['headline'] = df['headline'].apply(extract_main)

# %%
df.head()
# Out:
#                                             abstract  \
# 0  Economic hardship, climate change, political i...
# 1  It’s election night in America. Stay away from...
# 2  Tom is stressed in dress shoes, Shiv hides ben...
# 3  No corrections appeared in print on Monday, Ma...
# 4     Quotation of the Day for Monday, May 15, 2023.
#
#                                             headline  \
# 0  Title 42 Is Gone, but Not the Conditions Drivi...
# 1  ‘Succession’ Season 4, Episode 8 Recap: The Wi...
# 2  ‘Succession’ Style, Episode 8: Some People Jus...
# 3                       No Corrections: May 15, 2023
# 4  Quotation of the Day: When Your Champions Leag...
#
#                    pub_date document_type section_name type_of_material
# 0 2023-05-15 01:24:42+00:00       article         U.S.             News
# 1 2023-05-15 02:01:05+00:00       article         Arts             News
# 2 2023-05-15 02:15:04+00:00       article        Style             News
# 3 2023-05-15 03:55:48+00:00       article  Corrections             News
# 4 2023-05-15 03:55:57+00:00       article  Corrections             News

# %%
# Use the first 2000 abstracts for the analysis
abstracts = df['abstract'][-6000:]
docs = abstracts.to_list()

# %%
# Tokenize the documents.

from nltk.tokenize import RegexpTokenizer

# Split the documents into tokens.
tokenizer = RegexpTokenizer(r'\w+')
for idx in range(len(docs)):
    docs[idx] = docs[idx].lower()  # Convert to lowercase.
    docs[idx] = tokenizer.tokenize(docs[idx])  # Split into words.

# Remove numbers, but not words that contain numbers.
docs = [[token for token in doc if not token.isnumeric()] for doc in docs]

# Remove words that are only one character.
docs = [[token for token in doc if len(token) > 1] for doc in docs]

# %%
# Lemmatize the documents.
import nltk
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer

# Lemmatize all words in documents.
lemmatizer = WordNetLemmatizer()
docs = [[lemmatizer.lemmatize(token) for token in doc] for doc in docs]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/craigfranze/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Compute bigrams.

from gensim.models import Phrases

# Add bigrams and trigrams to docs (only ones that appear 20 times or more).
bigram = Phrases(docs, min_count=20)
for idx in range(len(docs)):
    for token in bigram[docs[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs[idx].append(token)

# %%
# Remove rare and common tokens.

from gensim.corpora import Dictionary

# Create a dictionary representation of the documents.
dictionary = Dictionary(docs)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=20, no_above=0.5)

# %%
docs[3]
# Out:
# ['ha', 'liberalism', 'found', 'coherent', 'sexual', 'ethic']

# %%
# Vectorize data.

# Bag-of-words representation of the documents.
#corpus = [dictionary.doc2bow(doc) for doc in docs]

# %%
import nltk
from nltk.corpus import stopwords

# Download stopwords if not already downloaded
nltk.download('stopwords')

# Define the stopwords
stop_words = set(stopwords.words('english'))

# Remove stopwords from each document
filtered_docs = [[word for word in doc if word not in stop_words] for doc in docs]

# Concatenate each entry into a single string after removing stopwords
cleaned_docs = [' '.join(doc) for doc in filtered_docs]

# Example of how to print the filtered and concatenated result for the first document
print(cleaned_docs[3])
# Out:
# ha liberalism found coherent sexual ethic
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/craigfranze/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
cleaned_docs[1]
# Out:
# 'patrick carfizzi vibrant performer supporting role ha grabbed attention new production verdi la forza del destino'

# %% [markdown]
# # BERTopic

# %%
from bertopic import BERTopic

# %%
# Concatenate each entry into a single string
#concatenated_docs = [' '.join(doc) for doc in docs]

# %%
# model = BERTopic(nr_topics=5) # Default number of topics is 30
model = BERTopic(verbose=True)

# %%
model.fit(cleaned_docs)
# Out:
# 2024-05-27 10:46:00,586 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/188 [00:00<?, ?it/s]
# 2024-05-27 10:46:47,090 - BERTopic - Embedding - Completed ✓
# 2024-05-27 10:46:47,091 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-27 10:47:08,457 - BERTopic - Dimensionality - Completed ✓
# 2024-05-27 10:47:08,458 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-27 10:47:08,656 - BERTopic - Cluster - Completed ✓
# 2024-05-27 10:47:08,661 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-27 10:47:08,826 - BERTopic - Representation - Completed ✓

# %%
topics, probabilities = model.transform(cleaned_docs)
# Out:
# Batches:   0%|          | 0/188 [00:00<?, ?it/s]
# 2024-05-27 10:48:00,035 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2024-05-27 10:48:00,053 - BERTopic - Dimensionality - Completed ✓
# 2024-05-27 10:48:00,053 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2024-05-27 10:48:00,265 - BERTopic - Cluster - Completed ✓

# %%
model.get_topic_freq().head(10)
# Out:
#     Topic  Count
# 2      -1   2030
# 23      0    345
# 1       1    323
# 11      2    252
# 3       3    239
# 0       4    149
# 25      5    136
# 7       6    120
# 21      7     95
# 19      8     95

# %%
model.visualize_topics()

# %%
model.visualize_barchart()

# %%
model.visualize_heatmap()

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                          Name  \
# 0      -1   2030                             -1_wa_new_said_ha
# 1       0    345              0_trump_donald_donaldtrump_trial
# 2       1    323              1_president_election_voter_party
# 3       2    252                   2_art_museum_artist_fashion
# 4       3    239                      3_film_movie_show_series
# ..    ...    ...                                           ...
# 79     78     11  78_orchestra_conductor_philharmonic_director
# 80     79     11         79_economy_optimistic_bad_demographer
# 81     80     10                   80_fossil_gas_drilling_fuel
# 82     81     10               81_debut_crossword_york_newyork
# 83     82     10                   82_damaged_sank_beach_barge
#
#                                        Representation  \
# 0   [wa, new, said, ha, year, one, time, also, sta...
# 1   [trump, donald, donaldtrump, trial, criminal, ...
# 2   [president, election, voter, party, biden, tru...
# 3   [art, museum, artist, fashion, work, designer,...
# 4   [film, movie, show, series, netflix, star, com...
# ..                                                ...
# 79  [orchestra, conductor, philharmonic, director,...
# 80  [economy, optimistic, bad, demographer, tempti...
# 81  [fossil, gas, drilling, fuel, mining, say, nat...
# 82  [debut, crossword, york, newyork, make, time, ...
# 83  [damaged, sank, beach, barge, whale, cruise, b...
#
#                                   Representative_Docs
# 0   [housing advocate even homeowner wealthier nei...
# 1   [jury selection begin monday donald trump hush...
# 2   [former president donald trump wa due hold cam...
# 3   [special section new york time museum highligh...
# 4   [look back george romero film one influential ...
# ..                                                ...
# 79  [thursday richly talented year old maestro led...
# 80  [economist explains lens make much optimistic ...
# 81  [shell others say plan drill oil gas gulf mexi...
# 82  [jake bunch make new york time crossword debut...
# 83  [barge carrying coal damaged marina one barge ...
#
# [84 rows x 5 columns]

# %%
report = model.get_topic_info()

# %%
report = pd.DataFrame(report)

# %% [markdown]
# # Topic Labeling with Ollama

# %%
import langchain

# %%
from langchain_community.llms import Ollama

llm = Ollama(model="llama2", temperature=0.01)

# %%
print(llm.invoke('Tell me a joke. Do not be conversational.'))
# Out:
# Why was the math book sad?
#
# Because it had too many problems.

# %%
system_prompt = 'You are a helpful, respectful and honest assistant for labeling topics.'
main_prompt_1 =  'I have a topic that contains the following documents: '
main_prompt_2 =  'The topic is described by the following keywords: '
main_prompt_3 =  'Based on the information about the topic above, please create a short label (no more than 10 words) of this topic.'
main_prompt_4 =  'Note that you only return the label and nothing more (no explanation or suggestions).'
main_prompt_5 =  'If you cant provide a label, return No Labels Available.'

# %%
# Concatenate the various parts into a single string, broken down for readability
prompt = (
    system_prompt + 
    main_prompt_1 + 
    str(report['Representative_Docs'].iloc[0]) + 
    main_prompt_2 + 
    str(report['Representation'].iloc[0]) + 
    main_prompt_3 + 
    main_prompt_4 + 
    main_prompt_5
)

# %%
topics = []
for i in range(len(report)):
    prompt = (system_prompt + 
              main_prompt_1 + 
              str(report['Representative_Docs'].iloc[i]) + 
              main_prompt_2 + str(report['Representation'].iloc[i]) + 
              main_prompt_3 + 
              main_prompt_4 + 
              main_prompt_5)
    topics.append(llm.invoke(prompt))

# %%
topics
# Out:
# ['Label: New York Property Tax System',
#  'Label: Trump Criminal Trial',
#  'Label: Presidential Election',
#  'Label: Art Exhibitions in New York and Denver',
#  'Label: Horror Movie Revival',
#  'Sure! Based on the information provided, here is a short label for the topic: "Pop Superstar\'s Latest Album Reigns at Billboard"',
#  'Modern Love Miniature',
#  'Label: China-US Trade Tensions',
#  'In Gaza, Israel launches invasion; US withholds aid.',
#  'Ukraine-Russia Conflict',
#  'Palestinian Protests on Campus',
#  'Easy Pasta & Chicken Dinner',
#  'Label: Mental Health Interventions',
#  'Israel strikes Iran',
#  'Sure! Based on the information provided, here is a short label for the topic:\n\nPremier League Sports',
#  'Abortion Policy and Rights in Florida and Arizona',
#  'Certainly! Based on the information provided, here is a short label for the topic:\n\n"Columbia University protest"',
#  'Label: Company Investment Deal',
#  'Label: Inflation Rate Decision',
#  'Label: Harvey Weinstein Sex Crime Conviction Overturned in New York',
#  'Feeling Stuck Today Puzzle Help',
#  'Label: Drug Policy Debate',
#  'Total Solar Eclipse',
#  'Label: School Education Selective Student College Problem Charter Financial District Harlem',
#  'TikTok Ban Topic',
#  'Label: "Hints for Today\'s Connection"',
#  'Label: Puzzle Help Needed',
#  'Label: Animal Identification in North Carolina',
#  'Label: This word appeared on NYTimes com past year',
#  'Label: Motherhood',
#  'Ceasefire in Gaza',
#  'Label: Bird Flu Outbreak in New York',
#  'Label: Artificial Intelligence',
#  'Label: New York City Political Scandal',
#  'Label: Prisoner Detention',
#  'Label: Ship Struck Bridge in Baltimore',
#  'Label: Quotation Day Monday April',
#  'Label: PFAS in Drinking Water',
#  'Label: Dance Company Premiere',
#  'Label: Image Captioning',
#  'Label: Print corrections in April',
#  'Label: Bachelor Couple Met',
#  'Label: Aid Package in Congress',
#  'Label: Heavy Rain in East Africa',
#  'Tornado Watch Tuesday in Texas, Oklahoma',
#  'Label: Worker Organizing in Automobile Industry',
#  'Label: "Today\'s Letter Reveal"',
#  'Police Officer Shot',
#  'Home Mortgage Seller Agent Estate Buyer Market',
#  'Sure! Based on the information provided, here is a possible short label for the topic:\n\n"Deportation of Haitian asylum seekers to Rwanda"',
#  'Sure! Based on the information provided, here is a short label for the topic:\n\nMidcentury Beach Retreats',
#  'Label: Journalism Bias in NPR Coverage',
#  'Label: Restaurant News in Brooklyn',
#  'Label: Quotation Day April',
#  'Label: Earthquake in Hualien',
#  'Label: Boeing Safety Concerns',
#  'Label: New York City Weekly Diary',
#  'Sure! Based on the information provided, here is a short label for the topic:\n\nSocial Media Subculture',
#  'Label: Simpson Murder Trial',
#  'Label: Property This Week',
#  'Rent and Housing Topic',
#  'Label: Crypto Exchange Scandals',
#  'Tony Nominations in Theater',
#  'Ecuador ex-VP Glas seeks refuge in Mexican embassy',
#  'Label: Poetry and Nature',
#  'Correction Appeared in Print on Tuesday',
#  'Label: Relationship Discussion',
#  'Label: Winning Essays by Age',
#  'Benjamin Netanyahu Under Investigation',
#  "Label: This Month's Movie Offerings",
#  'Sure! Based on the information provided, here is a short label for the topic: "Injured in stabbing attack on Saturday"',
#  'Label: Ethicist Columnist Debates Inherent Value of Human Life',
#  'Label: Murder and Guilty Plea',
#  'Columbia Antisemitism Hearing',
#  'Label: Editorial Suggestions for New York Times Readers',
#  'Label: Healthcare Payment and Data Security',
#  'Gaza War Tragedy',
#  'Label: Church Renovation in Harlem',
#  'Label: Extreme Heat and Temperature Records',
#  'Label: Next Music Director',
#  'Optimistic Economic Outlook',
#  'Label: Fossil Fuels Drilling',
#  'Label: New York Times Crossword Debuts',
#  'Marine Disasters']

# %%
report['Name'] = topics

# %%
pd.set_option('display.max_rows', None)

# %%
report.head(84)
# Out:
#     Topic  Count                                               Name  \
# 0      -1   2030                Label: New York Property Tax System
# 1       0    345                        Label: Trump Criminal Trial
# 2       1    323                       Label: Presidential Election
# 3       2    252      Label: Art Exhibitions in New York and Denver
# 4       3    239                        Label: Horror Movie Revival
# 5       4    149  Sure! Based on the information provided, here ...
# 6       5    136                              Modern Love Miniature
# 7       6    120                     Label: China-US Trade Tensions
# 8       7     95  In Gaza, Israel launches invasion; US withhold...
# 9       8     95                            Ukraine-Russia Conflict
# 10      9     92                     Palestinian Protests on Campus
# 11     10     88                        Easy Pasta & Chicken Dinner
# 12     11     82                 Label: Mental Health Interventions
# 13     12     81                                Israel strikes Iran
# 14     13     80  Sure! Based on the information provided, here ...
# 15     14     78  Abortion Policy and Rights in Florida and Arizona
# 16     15     73  Certainly! Based on the information provided, ...
# 17     16     63                     Label: Company Investment Deal
# 18     17     61                     Label: Inflation Rate Decision
# 19     18     51  Label: Harvey Weinstein Sex Crime Conviction O...
# 20     19     50                    Feeling Stuck Today Puzzle Help
# 21     20     49                          Label: Drug Policy Debate
# 22     21     44                                Total Solar Eclipse
# 23     22     42  Label: School Education Selective Student Coll...
# 24     23     38                                   TikTok Ban Topic
# 25     24     37              Label: "Hints for Today's Connection"
# 26     25     36                          Label: Puzzle Help Needed
# 27     26     36     Label: Animal Identification in North Carolina
# 28     27     35  Label: This word appeared on NYTimes com past ...
# 29     28     35                                  Label: Motherhood
# 30     29     34                                  Ceasefire in Gaza
# 31     30     34               Label: Bird Flu Outbreak in New York
# 32     31     34                     Label: Artificial Intelligence
# 33     32     30             Label: New York City Political Scandal
# 34     33     30                          Label: Prisoner Detention
# 35     34     28             Label: Ship Struck Bridge in Baltimore
# 36     35     27                  Label: Quotation Day Monday April
# 37     36     26                      Label: PFAS in Drinking Water
# 38     37     26                      Label: Dance Company Premiere
# 39     38     26                            Label: Image Captioning
# 40     39     25                  Label: Print corrections in April
# 41     40     24                         Label: Bachelor Couple Met
# 42     41     24                     Label: Aid Package in Congress
# 43     42     23                   Label: Heavy Rain in East Africa
# 44     43     23           Tornado Watch Tuesday in Texas, Oklahoma
# 45     44     23    Label: Worker Organizing in Automobile Industry
# 46     45     23                     Label: "Today's Letter Reveal"
# 47     46     23                                Police Officer Shot
# 48     47     22     Home Mortgage Seller Agent Estate Buyer Market
# 49     48     21  Sure! Based on the information provided, here ...
# 50     49     21  Sure! Based on the information provided, here ...
# 51     50     21             Label: Journalism Bias in NPR Coverage
# 52     51     21                 Label: Restaurant News in Brooklyn
# 53     52     21                         Label: Quotation Day April
# 54     53     21                       Label: Earthquake in Hualien
# 55     54     20                      Label: Boeing Safety Concerns
# 56     55     19                  Label: New York City Weekly Diary
# 57     56     19  Sure! Based on the information provided, here ...
# 58     57     19                        Label: Simpson Murder Trial
# 59     58     18                          Label: Property This Week
# 60     59     18                             Rent and Housing Topic
# 61     60     18                    Label: Crypto Exchange Scandals
# 62     61     18                        Tony Nominations in Theater
# 63     62     17  Ecuador ex-VP Glas seeks refuge in Mexican emb...
# 64     63     17                           Label: Poetry and Nature
# 65     64     17            Correction Appeared in Print on Tuesday
# 66     65     17                     Label: Relationship Discussion
# 67     66     16                       Label: Winning Essays by Age
# 68     67     16             Benjamin Netanyahu Under Investigation
# 69     68     16                Label: This Month's Movie Offerings
# 70     69     14  Sure! Based on the information provided, here ...
# 71     70     14  Label: Ethicist Columnist Debates Inherent Val...
# 72     71     14                      Label: Murder and Guilty Plea
# 73     72     13                      Columbia Antisemitism Hearing
# 74     73     13  Label: Editorial Suggestions for New York Time...
# 75     74     13        Label: Healthcare Payment and Data Security
# 76     75     12                                   Gaza War Tragedy
# 77     76     12                 Label: Church Renovation in Harlem
# 78     77     12        Label: Extreme Heat and Temperature Records
# 79     78     11                         Label: Next Music Director
# 80     79     11                        Optimistic Economic Outlook
# 81     80     10                       Label: Fossil Fuels Drilling
# 82     81     10             Label: New York Times Crossword Debuts
# 83     82     10                                   Marine Disasters
#
#                                        Representation  \
# 0   [wa, new, said, ha, year, one, time, also, sta...
# 1   [trump, donald, donaldtrump, trial, criminal, ...
# 2   [president, election, voter, party, biden, tru...
# 3   [art, museum, artist, fashion, work, designer,...
# 55  [whistle blower engineer say section plane bod...
# 56  [missing morning ritual accidental act recycli...
# 57  [cottage industry blog social medium account r...
# 58  [negotiated mr simpson star turn commercial ta...
# 59  [week property five bedroom home paramus chapp...
# 60  [lease rental bond guarantee cover loss tenant...
# 61  [compliance officer cryptocurrency exchange to...
# 62  [maleah joi moon almost gave theater first pro...
# 63  [former vice president jorge glas taken pill p...
# 64  [poet laureate ada limón mission reconnect u n...
# 65  [correction appeared print sunday april correc...
# 66  [young woman asked tiktok whether man wa datin...
# 67  [winning essay jacob wang age, winning essay s...
# 68  [benjamin netanyahu israeli prime minister los...
# 69  [month pick include true story hope persistenc...
# 70  [shopper hid backroom ran screaming scene othe...
# 71  [magazine ethicist columnist whether inherent ...
# 72  [dozen correctional worker urged gov mike pars...
# 73  [columbia university president nemat shafik sp...
# 74  [suggested reading critic editor new york time...
# 75  [data analytics firm ha helped big health insu...
# 76  [demonstrator unfurled banner name year old gi...
# 77  [used church first african methodist episcopal...
# 78  [climate change making heat wave linger longer...
# 79  [thursday richly talented year old maestro led...
# 80  [economist explains lens make much optimistic ...
# 81  [shell others say plan drill oil gas gulf mexi...
# 82  [jake bunch make new york time crossword debut...
# 83  [barge carrying coal damaged marina one barge ...

# %%
# Find the articles in the dataset that are representative of the topic
print(report['Name'].iloc[22] + '\n' + '---')
for i in range(len(report['Representative_Docs'].iloc[22])):
    search_string = report['Representative_Docs'].iloc[22][i]
    index = -1
    for j, doc in enumerate(cleaned_docs):
        if search_string in doc:
            index = j
            break
    print(abstracts.iloc[index]+ '\n' + '---')
# Out:
# Total Solar Eclipse
# ---
# Plus, is it eclipse weather?
# ---
# As millions of Americans prepare to see a total solar eclipse, a retired astrophysicist known as “Mr. Eclipse,” discusses the celestial phenomenon.
# ---
# We cover the solar eclipse that captivated the U.S.
# ---

# %%
# Get the topic for each document
model.get_document_info(cleaned_docs).head(5)
# A groupby could be used to get the top n documents for each topic
# Out:
#                                             Document  Topic  \
# 0  singer lizzo ha new swim line ha moved body po...      4
# 1  patrick carfizzi vibrant performer supporting ...      4
# 2  vote history data support polling showing bide...      1
# 3          ha liberalism found coherent sexual ethic     -1
# 4  need start asking better question kind work te...     -1
#
#                                Name  \
# 0        4_album_track_music_singer
# 1        4_album_track_music_singer
# 2  1_president_election_voter_party
# 3                 -1_wa_new_said_ha
# 4                 -1_wa_new_said_ha
#
#                                       Representation  \
# 0  [album, track, music, singer, song, musician, ...
# 1  [album, track, music, singer, song, musician, ...
# 2  [president, election, voter, party, biden, tru...
# 3  [wa, new, said, ha, year, one, time, also, sta...
# 4  [wa, new, said, ha, year, one, time, also, sta...
#
#                                  Representative_Docs  \
# 0  [beatles lp pop superstar reign atop billboard...
# 1  [beatles lp pop superstar reign atop billboard...
# 2  [former president donald trump wa due hold cam...
# 3  [housing advocate even homeowner wealthier nei...
# 4  [housing advocate even homeowner wealthier nei...
#
#                                          Top_n_words  Probability  \
# 0  album - track - music - singer - song - musici...     0.969447
# 1  album - track - music - singer - song - musici...     0.769767
# 2  president - election - voter - party - biden -...     1.000000
# 3  wa - new - said - ha - year - one - time - als...     0.000000
# 4  wa - new - said - ha - year - one - time - als...     0.000000
#
#    Representative_document
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
